# %%
import gym
from gym.envs.toy_text.frozen_lake import generate_random_map

# %%
# env_fl = gym.make("FrozenLake-v0")
env_fl = gym.make("FrozenLake-v1")
env_fl.reset()                    
env_fl.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %%
# !git clone https://github.com/ARG-NCTU/gym-duckienav.git 
# %cd gym-duckienav
# !pip install -e .
# Out:
# c:\Users\d7757\Desktop\Learn_Gym\gym-duckienav
# fatal: destination path 'gym-duckienav' already exists and is not an empty directory.
# Obtaining file:///C:/Users/d7757/Desktop/Learn_Gym/gym-duckienav
# Requirement already satisfied: gym in c:\users\d7757\miniconda3\envs\ai_intro_03_01\lib\site-packages (from gym-duckienav==0.0.1) (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\d7757\miniconda3\envs\ai_intro_03_01\lib\site-packages (from gym->gym-duckienav==0.0.1) (1.21.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\d7757\miniconda3\envs\ai_intro_03_01\lib\site-packages (from gym->gym-duckienav==0.0.1) (2.0.0)
# Installing collected packages: gym-duckienav
#   Attempting uninstall: gym-duckienav
#     Found existing installation: gym-duckienav 0.0.1
#     Uninstalling gym-duckienav-0.0.1:
#       Successfully uninstalled gym-duckienav-0.0.1
#   Running setup.py develop for gym-duckienav
# Successfully installed gym-duckienav-0.0.1

# %%
import gym
import gym_duckienav
import gym.spaces
import numpy as np

env = gym.make("DuckieNav-v2")

# %%
env.reset()
env.render()
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+

# %%
env.observation_space.n
# Out:
# 2520

# %%
env.action_space.n
# Out:
# 6

# %%
env.reset()

print("Current state: ", str(env.s))
for p in env.decode(env.s): print(p)
env.render()
# Out:
# Current state:  681
# 3
# 7
# 0
# 1
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+

# %%
ACTIONS = ["South", "North", "East", "West", "Pickup", "Dropoff"]
env.s = 124
env.render()
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+

# %%
state, reward, done, info = env.step(4)
env.render()
print("reward: ", str(reward))
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Pickup)
# reward:  -10

# %%
state, reward, done, info = env.step(2)
env.render()
print("reward: ", str(reward))
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (East)
# reward:  -50

# %%
state, reward, done, info = env.step(4)
env.render()
print("reward: ", str(reward))
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Pickup)
# reward:  -10

# %%
state, reward, done, info = env.step(3)
env.render()
print("reward: ", str(reward))
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# reward:  -1

# %%
for i in range(0, 5):
    env.step(0)
env.render()
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (South)

# %%
state, reward, done, info = env.step(5)
env.render()
print("reward: ", str(reward))
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Dropoff)
# reward:  -50

# %%
for i in range(0, 4):
    env.step(3)
env.render()
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)

# %%
state, reward, done, info = env.step(5)
env.render()
print("reward: ", str(reward))
print("done: ", str(done))
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Dropoff)
# reward:  -50
# done:  False

# %%
print(env.action_space.sample())
# Out:
# 1

# %%
state = env.reset()

counter = 0
g = 0
reward = None
while reward != 20:
    state, reward, done, info = env.step(env.action_space.sample())
    counter += 1
    g += reward
print("Solved in {} Steps with a total reward of {}".format(counter,g))
# Out:
# Solved in 7556 Steps with a total reward of -190544

# %%
n_states = env.observation_space.n
n_actions = env.action_space.n
Q = np.zeros([n_states, n_actions])
ACTIONS = ["South", "North", "East", "West", "Pickup", "Dropoff"]

episodes = 1
G = 0
counter = 0
alpha = 0.618

for episode in range(1,episodes+1):
    done = False
    G, reward = 0,0

    state = env.reset()
    env.render()
    print("Step: {}, Action: {}, Reward: {}, Q[{}] \t{}".format("   ", "   ", "   ", "   ", ACTIONS))

    firstState = state
    print("Initial State = {}".format(state))
    while reward != 20:
        action = np.argmax(Q[state])  #1
        state2, reward, done, info = env.step(action) #2

        if counter < 20:
            print("Before Step: {}, Action: {}, Reward: {}, Q[{}] \t{}".format(counter, ACTIONS[action], reward, state, Q[state]))
            print("Future Step: {}, Action: {}, Reward: {}, Q[{}] \t{}".format(counter, ACTIONS[action], reward, state2, Q[state2]))

        Q[state,action] += alpha * (reward + np.max(Q[state2]) - Q[state,action]) #3
        
        if counter < 20:
            print("After  Step: {}, Action: {}, Reward: {}, Q[{}] \t{}".format(counter, ACTIONS[action], reward, state, Q[state]))
            print("--------")

        counter += 1
        G += reward
        state = state2
        
finalState = state
print("Final State = {}".format(finalState))
print("Solved in {} Steps with a total reward of {}".format(counter, G))
env.render()

print(ACTIONS)
print(Q[finalState])
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#
# Step:    , Action:    , Reward:    , Q[   ] 	['South', 'North', 'East', 'West', 'Pickup', 'Dropoff']
# Initial State = 1422
# Before Step: 0, Action: South, Reward: -1, Q[1422] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 0, Action: South, Reward: -1, Q[1602] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 0, Action: South, Reward: -1, Q[1422] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 1, Action: South, Reward: -1, Q[1602] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 1, Action: South, Reward: -1, Q[1782] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 1, Action: South, Reward: -1, Q[1602] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 2, Action: South, Reward: -1, Q[1782] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 2, Action: South, Reward: -1, Q[1962] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 2, Action: South, Reward: -1, Q[1782] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 3, Action: South, Reward: -1, Q[1962] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 3, Action: South, Reward: -1, Q[2142] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 3, Action: South, Reward: -1, Q[1962] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 4, Action: South, Reward: -1, Q[2142] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 4, Action: South, Reward: -1, Q[2322] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 4, Action: South, Reward: -1, Q[2142] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 5, Action: South, Reward: -50, Q[2322] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 5, Action: South, Reward: -50, Q[2502] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 5, Action: South, Reward: -50, Q[2322] 	[-30.9   0.    0.    0.    0.    0. ]
# --------
# Before Step: 6, Action: South, Reward: -50, Q[2502] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 6, Action: South, Reward: -50, Q[2502] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 6, Action: South, Reward: -50, Q[2502] 	[-30.9   0.    0.    0.    0.    0. ]
# --------
# Before Step: 7, Action: North, Reward: -1, Q[2502] 	[-30.9   0.    0.    0.    0.    0. ]
# Future Step: 7, Action: North, Reward: -1, Q[2322] 	[-30.9   0.    0.    0.    0.    0. ]
# After  Step: 7, Action: North, Reward: -1, Q[2502] 	[-30.9    -0.618   0.      0.      0.      0.   ]
# --------
# Before Step: 8, Action: North, Reward: -1, Q[2322] 	[-30.9   0.    0.    0.    0.    0. ]
# Future Step: 8, Action: North, Reward: -1, Q[2142] 	[-0.618  0.     0.     0.     0.     0.   ]
# After  Step: 8, Action: North, Reward: -1, Q[2322] 	[-30.9    -0.618   0.      0.      0.      0.   ]
# --------
# Before Step: 9, Action: North, Reward: -1, Q[2142] 	[-0.618  0.     0.     0.     0.     0.   ]
# Future Step: 9, Action: North, Reward: -1, Q[1962] 	[-0.618  0.     0.     0.     0.     0.   ]
# After  Step: 9, Action: North, Reward: -1, Q[2142] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# --------
# Before Step: 10, Action: North, Reward: -1, Q[1962] 	[-0.618  0.     0.     0.     0.     0.   ]
# Future Step: 10, Action: North, Reward: -1, Q[1782] 	[-0.618  0.     0.     0.     0.     0.   ]
# After  Step: 10, Action: North, Reward: -1, Q[1962] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# --------
# Before Step: 11, Action: North, Reward: -1, Q[1782] 	[-0.618  0.     0.     0.     0.     0.   ]
# Future Step: 11, Action: North, Reward: -1, Q[1602] 	[-0.618  0.     0.     0.     0.     0.   ]
# After  Step: 11, Action: North, Reward: -1, Q[1782] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# --------
# Before Step: 12, Action: North, Reward: -1, Q[1602] 	[-0.618  0.     0.     0.     0.     0.   ]
# Future Step: 12, Action: North, Reward: -1, Q[1422] 	[-0.618  0.     0.     0.     0.     0.   ]
# After  Step: 12, Action: North, Reward: -1, Q[1602] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# --------
# Before Step: 13, Action: North, Reward: -1, Q[1422] 	[-0.618  0.     0.     0.     0.     0.   ]
# Future Step: 13, Action: North, Reward: -1, Q[1242] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 13, Action: North, Reward: -1, Q[1422] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# --------
# Before Step: 14, Action: South, Reward: -1, Q[1242] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 14, Action: South, Reward: -1, Q[1422] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# After  Step: 14, Action: South, Reward: -1, Q[1242] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 15, Action: East, Reward: -50, Q[1422] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# Future Step: 15, Action: East, Reward: -50, Q[1422] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# After  Step: 15, Action: East, Reward: -50, Q[1422] 	[ -0.618  -0.618 -30.9     0.      0.      0.   ]
# --------
# Before Step: 16, Action: West, Reward: -1, Q[1422] 	[ -0.618  -0.618 -30.9     0.      0.      0.   ]
# Future Step: 16, Action: West, Reward: -1, Q[1402] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 16, Action: West, Reward: -1, Q[1422] 	[ -0.618  -0.618 -30.9    -0.618   0.      0.   ]
# --------
# Before Step: 17, Action: South, Reward: -50, Q[1402] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 17, Action: South, Reward: -50, Q[1582] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 17, Action: South, Reward: -50, Q[1402] 	[-30.9   0.    0.    0.    0.    0. ]
# --------
# Before Step: 18, Action: South, Reward: -50, Q[1582] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 18, Action: South, Reward: -50, Q[1762] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 18, Action: South, Reward: -50, Q[1582] 	[-30.9   0.    0.    0.    0.    0. ]
# --------
# Before Step: 19, Action: South, Reward: -50, Q[1762] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 19, Action: South, Reward: -50, Q[1942] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 19, Action: South, Reward: -50, Q[1762] 	[-30.9   0.    0.    0.    0.    0. ]
# --------
# Final State = 2418
# Solved in 39667 Steps with a total reward of -166802
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Dropoff)
# ['South', 'North', 'East', 'West', 'Pickup', 'Dropoff']
# [-30.9   -30.9    -0.618  -0.618  -6.18   12.36 ]

# %%
print(str(np.count_nonzero(Q)), " / ", str(n_states * n_actions))
# Out:
# 2863  /  15120

# %%
episodes = 10000

G = 0
alpha = 0.618

for episode in range(1,episodes+1):
    done = False
    G, reward = 0,0

    state = env.reset()

    while done != True:
        action = np.argmax(Q[state]) 
        state2, reward, done, info = env.step(action) 
        Q[state,action] += alpha * ((reward + (np.max(Q[state2]))  - Q[state,action]))
        G += reward
        state = state2
    
    if episode % 100 == 0:
        print('Episode {} Total Reward: {}'.format(episode,G))
    
print(str(np.count_nonzero(Q)), " / ", str(n_states * n_actions))
# Out:
# Episode 100 Total Reward: -292
# Episode 200 Total Reward: -135
# Episode 300 Total Reward: -203
# Episode 400 Total Reward: -102
# Episode 500 Total Reward: -30
# Episode 600 Total Reward: -96
# Episode 700 Total Reward: -94
# Episode 800 Total Reward: -154
# Episode 900 Total Reward: -302
# Episode 1000 Total Reward: -374
# Episode 1100 Total Reward: -47
# Episode 1200 Total Reward: -55
# Episode 1300 Total Reward: -44
# Episode 1400 Total Reward: -104
# Episode 1500 Total Reward: 7
# Episode 1600 Total Reward: -51
# Episode 1700 Total Reward: -59
# Episode 1800 Total Reward: -58
# Episode 1900 Total Reward: -49
# Episode 2000 Total Reward: -569
# Episode 2100 Total Reward: -4
# Episode 2200 Total Reward: -49
# Episode 2300 Total Reward: -44
# Episode 2400 Total Reward: -104
# Episode 2500 Total Reward: 4
# Episode 2600 Total Reward: -13
# Episode 2700 Total Reward: -111
# Episode 2800 Total Reward: 11
# Episode 2900 Total Reward: -69
# Episode 3000 Total Reward: -52
# Episode 3100 Total Reward: -44
# Episode 3200 Total Reward: -102
# Episode 3300 Total Reward: -59
# Episode 3400 Total Reward: -107
# Episode 3500 Total Reward: -62
# Episode 3600 Total Reward: -102
# Episode 3700 Total Reward: 8
# Episode 3800 Total Reward: -51
# Episode 3900 Total Reward: -44
# Episode 4000 Total Reward: -2
# Episode 4100 Total Reward: -58
# Episode 4200 Total Reward: -56
# Episode 4300 Total Reward: 2
# Episode 4400 Total Reward: -54
# Episode 4500 Total Reward: -51
# Episode 4600 Total Reward: -47
# Episode 4700 Total Reward: -44
# Episode 4800 Total Reward: -47
# Episode 4900 Total Reward: 2
# Episode 5000 Total Reward: -43
# Episode 5100 Total Reward: -45
# Episode 5200 Total Reward: -54
# Episode 5300 Total Reward: -4
# Episode 5400 Total Reward: -40
# Episode 5500 Total Reward: -102
# Episode 5600 Total Reward: -51
# Episode 5700 Total Reward: 10
# Episode 5800 Total Reward: -41
# Episode 5900 Total Reward: -70
# Episode 6000 Total Reward: -46
# Episode 6100 Total Reward: -65
# Episode 6200 Total Reward: -46
# Episode 6300 Total Reward: -1
# Episode 6400 Total Reward: -68
# Episode 6500 Total Reward: -119
# Episode 6600 Total Reward: -58
# Episode 6700 Total Reward: -107
# Episode 6800 Total Reward: 9
# Episode 6900 Total Reward: -57
# Episode 7000 Total Reward: -101
# Episode 7100 Total Reward: -102
# Episode 7200 Total Reward: -49
# Episode 7300 Total Reward: -53
# Episode 7400 Total Reward: -50
# Episode 7500 Total Reward: -54
# Episode 7600 Total Reward: -47
# Episode 7700 Total Reward: -57
# Episode 7800 Total Reward: -57
# Episode 7900 Total Reward: -2
# Episode 8000 Total Reward: -68
# Episode 8100 Total Reward: -55
# Episode 8200 Total Reward: -8
# Episode 8300 Total Reward: -119
# Episode 8400 Total Reward: -52
# Episode 8500 Total Reward: -53
# Episode 8600 Total Reward: 7
# Episode 8700 Total Reward: -56
# Episode 8800 Total Reward: -50
# Episode 8900 Total Reward: -50
# Episode 9000 Total Reward: -59
# Episode 9100 Total Reward: -45
# Episode 9200 Total Reward: -53
# Episode 9300 Total Reward: -7
# Episode 9400 Total Reward: -50
# Episode 9500 Total Reward: -44
# Episode 9600 Total Reward: -54
# Episode 9700 Total Reward: -46
# Episode 9800 Total Reward: -56
# Episode 9900 Total Reward: -51
# Episode 10000 Total Reward: -120
# 11554  /  15120

# %%
state = env.reset()

done = None

while done != True:
    # We simply take the action with the highest Q Value
    action = np.argmax(Q[state])
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Pickup)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : :_:Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O|_|O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : :_: : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O|_|O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : :_: : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O|_|O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O|_: : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| :_: |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (East)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : :_|O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (East)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O|_|O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: :_: : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R:_: : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Dropoff)

# %%
env.reset()
env.s = 124
env.render()
done = None
STEPS = []
ACTIONS = ["South", "North", "East", "West", "Pickup", "Dropoff"] 
total_reward = 0
while done != True:
  env.render()
  action = np.argmax(Q[env.s])
  STEPS.append(ACTIONS[action])
  env.s, reward, done, info = env.step(action)
  total_reward += reward
print(STEPS, total_reward, len(STEPS))
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (East)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (South)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (South)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (South)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (South)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (South)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (South)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (East)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Pickup)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y:_: : : : |
# +-----------------+
#   (East)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O|_|O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : :_: : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : :_: |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (East)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : :_|O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (East)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O|_|O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : :_|O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# ['East', 'West', 'West', 'West', 'South', 'South', 'South', 'South', 'South', 'South', 'East', 'Pickup', 'East', 'North', 'North', 'East', 'East', 'North', 'North', 'North', 'Dropoff'] -98 21

# %%
print(env.reset())
print(env.s)
# Out:
# 447
# 124

# %%
env.reset()
env.s = 124
env.render()
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+

# %%
def test_q_learning(env, Q, state):
    '''
    out_1: the sequence of actions
    out_2: total reward
    out_3: total steps
    '''
    done = None
    STEPS = []
    ACTIONS = ["South", "North", "East", "West", "Pickup", "Dropoff"] 
    total_reward = 0
    while done != True:
      action = np.argmax(Q[state])
      STEPS.append(ACTIONS[action])
      state, reward, done, info = env.step(action)
      total_reward += reward
    return STEPS, total_reward, len(STEPS)

    # done = None

    # out_1 = []
    # out_2 = 0
    # while done != True:
    #     # We simply take the action with the highest Q Value
    #     action = np.argmax(Q[state])
    #     print(ACTIONS[action])
    #     out_1.append(ACTIONS[action])
    #     state, reward, done, info = env.step(action)
    #     out_2 += reward
    # return out_1, out_2, len(out_1)
